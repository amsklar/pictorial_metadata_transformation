# %% [markdown]
# # Extracting, Transforming, & Ingesting Metadata

# %% [markdown]
# #### Load Libraries

# %%
import requests 
import json 
import csv
import os

# %% [markdown]
# ## Extracting Information

# %% [markdown]
# ### Collection Metadata

# %% [markdown]
# *Endpoint searches for items by map format, with a subject of pictorial maps, and returns up to 150 results.*

# %%
endpoint_collection = 'https://www.loc.gov/maps/?fa=subject%3Apictorial+maps&st=list&c=150'

# %%
r = requests.get(endpoint_collection, params={'fo':'json'})

# %%
pictorial_set = r.json()

# %%
with open('pictorial-set.json', 'w') as f:
    json.dump(pictorial_set, f, indent=2)

# %%
with open('pictorial-set.json', 'r') as json_file:
    pictorial_set = json.load(json_file)

csv_file_path = 'pictorial_collection.csv'

extract_keys_resources = ["image", "url"]
extract_keys_item = ["title"]

headers = extract_keys_item + extract_keys_resources

with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(headers)

    for result in pictorial_set.get("results", []):
        resources = result.get("resources", [])

        for resource in resources:
            row_resources = [resource.get(key, '') for key in extract_keys_resources]
            item_value = result.get("item", {})
            row_item = [item_value.get(key, '') for key in extract_keys_item]
            csv_writer.writerow(row_item + row_resources)

# %% [markdown]
# ### Item Metadata

# %%
error_count = 0
file_count = 0
item_count = 0

data_directory = os.makedirs('data', exist_ok=True)
item_metadata_file_start = 'item_metadata'
json_suffix = '.json'

endpoint_item = 'https://www.loc.gov/resource/'
with open(csv_file_path, 'r', newline='', encoding='utf-8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        url_value = row['url']
        id = url_value.split('/')[4]
        item_metadata = requests.get(endpoint_item + id, params={'fo':'json'})
        print('requested',item_metadata.url,item_metadata.status_code)
        if item_metadata.status_code != 200:
            print('requested',item_metadata.url,item_metadata.status_code)
            error_count += 1
            continue
        try:
            item_metadata.json()
        except:
            error_count += 1
            print('no json found')
            continue
        fout = os.path.join('data', str(item_metadata_file_start + '-' + id + json_suffix))
        with open(fout, 'w', encoding='utf-8') as json_file:
            json_file.write(json.dumps(item_metadata.json()['item']))
            file_count += 1
            print('wrote', fout)
        item_count += 1

print('items requested:',item_count)
print('errors:',error_count)
print('files written:',file_count)
# Out:
# requested https://www.loc.gov/resource/g7823g.ct003370?fo=json 200
# wrote data/item_metadata-g7823g.ct003370.json
# requested https://www.loc.gov/resource/g3803o.la000541?fo=json 200
# wrote data/item_metadata-g3803o.la000541.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.pa-184?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.pa-184.json
# requested https://www.loc.gov/resource/gmdtitlecolmaps.hi-013?fo=json 200
# wrote data/item_metadata-gmdtitlecolmaps.hi-013.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.hi-013?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.hi-013.json
# requested https://www.loc.gov/resource/g7824h.ct003399?fo=json 200
# wrote data/item_metadata-g7824h.ct003399.json
# requested https://www.loc.gov/resource/g7823x.ct003373?fo=json 200
# wrote data/item_metadata-g7823x.ct003373.json
# requested https://www.loc.gov/resource/g3851a.ct004563?fo=json 200
# wrote data/item_metadata-g3851a.ct004563.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ks-057?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ks-057.json
# requested https://www.loc.gov/resource/g7964k.ct011902?fo=json 200
# wrote data/item_metadata-g7964k.ct011902.json
# requested https://www.loc.gov/resource/g8001e.ct007688a?fo=json 200
# wrote data/item_metadata-g8001e.ct007688a.json
# requested https://www.loc.gov/resource/g8001e.ct007688b?fo=json 200
# wrote data/item_metadata-g8001e.ct007688b.json
# requested https://www.loc.gov/resource/g8001e.ct007688c?fo=json 200
# wrote data/item_metadata-g8001e.ct007688c.json
# requested https://www.loc.gov/resource/g8001e.ct007688d?fo=json 200
# wrote data/item_metadata-g8001e.ct007688d.json
# requested https://www.loc.gov/resource/g3734a.ct003779r?fo=json 200
# wrote data/item_metadata-g3734a.ct003779r.json
# requested https://www.loc.gov/resource/g3734a.ct003779v?fo=json 200
# wrote data/item_metadata-g3734a.ct003779v.json
# requested https://www.loc.gov/resource/g3734a.ct003780?fo=json 200
# wrote data/item_metadata-g3734a.ct003780.json
# requested https://www.loc.gov/resource/g5754l.ct003533?fo=json 200
# wrote data/item_metadata-g5754l.ct003533.json
# requested https://www.loc.gov/resource/g3851e.ct004632?fo=json 200
# wrote data/item_metadata-g3851e.ct004632.json
# requested https://www.loc.gov/resource/g3201a.ct007196?fo=json 200
# wrote data/item_metadata-g3201a.ct007196.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ks-013?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ks-013.json
# requested https://www.loc.gov/resource/g8314d.ct011331?fo=json 200
# wrote data/item_metadata-g8314d.ct011331.json
# requested https://www.loc.gov/resource/g8263t.pm020555?fo=json 200
# wrote data/item_metadata-g8263t.pm020555.json
# requested https://www.loc.gov/resource/g3201sm.gct00551?fo=json 200
# wrote data/item_metadata-g3201sm.gct00551.json
# requested https://www.loc.gov/resource/g7823m.ct003372?fo=json 200
# wrote data/item_metadata-g7823m.ct003372.json
# requested https://www.loc.gov/resource/g7822z.ct003289?fo=json 200
# wrote data/item_metadata-g7822z.ct003289.json
# requested https://www.loc.gov/resource/g7144b.ct002932?fo=json 200
# wrote data/item_metadata-g7144b.ct002932.json
# requested https://www.loc.gov/resource/g3701a.ct003098?fo=json 200
# wrote data/item_metadata-g3701a.ct003098.json
# requested https://www.loc.gov/resource/gmdtitlecolmaps.ca-012?fo=json 200
# wrote data/item_metadata-gmdtitlecolmaps.ca-012.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ca-012?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ca-012.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_14436?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_14436.json
# requested https://www.loc.gov/resource/g7823g.ct003302?fo=json 200
# wrote data/item_metadata-g7823g.ct003302.json
# requested https://www.loc.gov/resource/g7964t.ct011915?fo=json 200
# wrote data/item_metadata-g7964t.ct011915.json
# requested https://www.loc.gov/resource/g7823y.ct003377?fo=json 200
# wrote data/item_metadata-g7823y.ct003377.json
# requested https://www.loc.gov/resource/g7964k.ct011900?fo=json 200
# wrote data/item_metadata-g7964k.ct011900.json
# requested https://www.loc.gov/resource/g7824c.ct003297?fo=json 200
# wrote data/item_metadata-g7824c.ct003297.json
# requested https://www.loc.gov/resource/g7822q.ct003369?fo=json 200
# wrote data/item_metadata-g7822q.ct003369.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_18965?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_18965.json
# requested https://www.loc.gov/resource/g3851e.ct004633?fo=json 200
# wrote data/item_metadata-g3851e.ct004633.json
# requested https://www.loc.gov/resource/g7801r.ct002202a?fo=json 200
# wrote data/item_metadata-g7801r.ct002202a.json
# requested https://www.loc.gov/resource/g7801r.ct002202b?fo=json 200
# wrote data/item_metadata-g7801r.ct002202b.json
# requested https://www.loc.gov/resource/g7801r.ct002202c?fo=json 200
# wrote data/item_metadata-g7801r.ct002202c.json
# requested https://www.loc.gov/resource/g7801r.ct002202d?fo=json 200
# wrote data/item_metadata-g7801r.ct002202d.json
# requested https://www.loc.gov/resource/g7823d.ct003307?fo=json 200
# wrote data/item_metadata-g7823d.ct003307.json
# requested https://www.loc.gov/resource/g4084p.ct001213?fo=json 200
# wrote data/item_metadata-g4084p.ct001213.json
# requested https://www.loc.gov/resource/g3851a.ct004532?fo=json 200
# wrote data/item_metadata-g3851a.ct004532.json
# requested https://www.loc.gov/resource/g3701s.ct003097?fo=json 200
# wrote data/item_metadata-g3701s.ct003097.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_00503?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_00503.json
# requested https://www.loc.gov/resource/g7822ym.gct00273?fo=json 200
# wrote data/item_metadata-g7822ym.gct00273.json
# requested https://www.loc.gov/resource/gmdtitlecolmaps.ca-050?fo=json 200
# wrote data/item_metadata-gmdtitlecolmaps.ca-050.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ca-050?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ca-050.json
# requested https://www.loc.gov/resource/g7824t.ct003296?fo=json 200
# wrote data/item_metadata-g7824t.ct003296.json
# requested https://www.loc.gov/resource/gmdtitlecolmaps.ca-054?fo=json 200
# wrote data/item_metadata-gmdtitlecolmaps.ca-054.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ca-054?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ca-054.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ca-049?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ca-049.json
# requested https://www.loc.gov/resource/g4282g.ct003337?fo=json 200
# wrote data/item_metadata-g4282g.ct003337.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_14435_001?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_14435_001.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_14435_002?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_14435_002.json
# requested https://www.loc.gov/resource/g7822y.ct003437?fo=json 200
# wrote data/item_metadata-g7822y.ct003437.json
# requested https://www.loc.gov/resource/g3804n.ct011181?fo=json 200
# wrote data/item_metadata-g3804n.ct011181.json
# requested https://www.loc.gov/resource/g7823l.ct003378?fo=json 200
# wrote data/item_metadata-g7823l.ct003378.json
# requested https://www.loc.gov/resource/g9112n.ct011954?fo=json 200
# wrote data/item_metadata-g9112n.ct011954.json
# requested https://www.loc.gov/resource/g3844b.ct003394r?fo=json 200
# wrote data/item_metadata-g3844b.ct003394r.json
# requested https://www.loc.gov/resource/g3844b.ct003394v?fo=json 200
# wrote data/item_metadata-g3844b.ct003394v.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ca-033?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ca-033.json
# requested https://www.loc.gov/resource/g7824l.ct003306?fo=json 200
# wrote data/item_metadata-g7824l.ct003306.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.me-039?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.me-039.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_00502?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_00502.json
# requested https://www.loc.gov/resource/g7823z.ct003304?fo=json 200
# wrote data/item_metadata-g7823z.ct003304.json
# requested https://www.loc.gov/resource/g3701j.ct003099?fo=json 200
# wrote data/item_metadata-g3701j.ct003099.json
# requested https://www.loc.gov/resource/g5754s.ct003534?fo=json 200
# wrote data/item_metadata-g5754s.ct003534.json
# requested https://www.loc.gov/resource/g7822gm.gct00247?fo=json 200
# wrote data/item_metadata-g7822gm.gct00247.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_00457?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_00457.json
# requested https://www.loc.gov/resource/g7001sm.gct00411?fo=json 200
# wrote data/item_metadata-g7001sm.gct00411.json
# requested https://www.loc.gov/resource/gmdtitlecolmaps.hi-012?fo=json 200
# wrote data/item_metadata-gmdtitlecolmaps.hi-012.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.hi-012?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.hi-012.json
# requested https://www.loc.gov/resource/g4282g.ct003338?fo=json 200
# wrote data/item_metadata-g4282g.ct003338.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_00407?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_00407.json
# requested https://www.loc.gov/resource/g7964t.ct002120?fo=json 200
# wrote data/item_metadata-g7964t.ct002120.json
# requested https://www.loc.gov/resource/g7823b.ct003288?fo=json 200
# wrote data/item_metadata-g7823b.ct003288.json
# requested https://www.loc.gov/resource/g4104c.ct003853?fo=json 200
# wrote data/item_metadata-g4104c.ct003853.json
# requested https://www.loc.gov/resource/g7964k.ct011896?fo=json 200
# wrote data/item_metadata-g7964k.ct011896.json
# requested https://www.loc.gov/resource/g4042m.ct003556?fo=json 200
# wrote data/item_metadata-g4042m.ct003556.json
# requested https://www.loc.gov/resource/g7001s.g2017588308?fo=json 200
# wrote data/item_metadata-g7001s.g2017588308.json
# requested https://www.loc.gov/resource/g7964t.ct011888?fo=json 200
# wrote data/item_metadata-g7964t.ct011888.json
# requested https://www.loc.gov/resource/g5752s.ct003531?fo=json 200
# wrote data/item_metadata-g5752s.ct003531.json
# requested https://www.loc.gov/resource/g3701a.ct003947?fo=json 200
# wrote data/item_metadata-g3701a.ct003947.json
# requested https://www.loc.gov/resource/g3291sm.grb00002?fo=json 200
# wrote data/item_metadata-g3291sm.grb00002.json
# requested https://www.loc.gov/resource/g3934s.ct000068?fo=json 200
# wrote data/item_metadata-g3934s.ct000068.json
# requested https://www.loc.gov/resource/g7824h.ct003295?fo=json 200
# wrote data/item_metadata-g7824h.ct003295.json
# requested https://www.loc.gov/resource/g3841pm.gct00485?fo=json 200
# wrote data/item_metadata-g3841pm.gct00485.json
# requested https://www.loc.gov/resource/g3742w.ct005513?fo=json 200
# wrote data/item_metadata-g3742w.ct005513.json
# requested https://www.loc.gov/resource/g7823h.ct003305a?fo=json 200
# wrote data/item_metadata-g7823h.ct003305a.json
# requested https://www.loc.gov/resource/g7823h.ct003305b?fo=json 200
# wrote data/item_metadata-g7823h.ct003305b.json
# requested https://www.loc.gov/resource/g3850.ct001035r?fo=json 200
# wrote data/item_metadata-g3850.ct001035r.json
# requested https://www.loc.gov/resource/g3850.ct001035v?fo=json 200
# wrote data/item_metadata-g3850.ct001035v.json
# requested https://www.loc.gov/resource/g4164s.ct003087?fo=json 200
# wrote data/item_metadata-g4164s.ct003087.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_00438?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_00438.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ks-009?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ks-009.json
# requested https://www.loc.gov/resource/g7823g.ct003390?fo=json 200
# wrote data/item_metadata-g7823g.ct003390.json
# requested https://www.loc.gov/resource/g7963s.ct001265?fo=json 200
# wrote data/item_metadata-g7963s.ct001265.json
# requested https://www.loc.gov/resource/g7823y.ct003376?fo=json 200
# wrote data/item_metadata-g7823y.ct003376.json
# requested https://www.loc.gov/resource/g4191s.ct007703?fo=json 200
# wrote data/item_metadata-g4191s.ct007703.json
# requested https://www.loc.gov/resource/g4282g.ct003339?fo=json 200
# wrote data/item_metadata-g4282g.ct003339.json
# requested https://www.loc.gov/resource/g7823m.ct003371?fo=json 200
# wrote data/item_metadata-g7823m.ct003371.json
# requested https://www.loc.gov/resource/g7964tm.gct00271a?fo=json 200
# wrote data/item_metadata-g7964tm.gct00271a.json
# requested https://www.loc.gov/resource/g7964tm.gct00271b?fo=json 200
# wrote data/item_metadata-g7964tm.gct00271b.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.pa-027?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.pa-027.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_00458?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_00458.json
# requested https://www.loc.gov/resource/g7822y.ct003303?fo=json 200
# wrote data/item_metadata-g7822y.ct003303.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ks-065?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ks-065.json
# requested https://www.loc.gov/resource/g7964o.ct011894?fo=json 200
# wrote data/item_metadata-g7964o.ct011894.json
# requested https://www.loc.gov/resource/g7964o.ct011916?fo=json 200
# wrote data/item_metadata-g7964o.ct011916.json
# requested https://www.loc.gov/resource/g7823s.ct003375?fo=json 200
# wrote data/item_metadata-g7823s.ct003375.json
# requested https://www.loc.gov/resource/g3804n.ct007809?fo=json 200
# wrote data/item_metadata-g3804n.ct007809.json
# requested https://www.loc.gov/resource/g3852n.ct005167?fo=json 200
# wrote data/item_metadata-g3852n.ct005167.json
# requested https://www.loc.gov/resource/g7822y.ct003438?fo=json 200
# wrote data/item_metadata-g7822y.ct003438.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.pa-160?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.pa-160.json
# requested https://www.loc.gov/resource/g7821a.ct007520?fo=json 200
# wrote data/item_metadata-g7821a.ct007520.json
# requested https://www.loc.gov/resource/g3803o.la000536?fo=json 200
# wrote data/item_metadata-g3803o.la000536.json
# requested https://www.loc.gov/resource/gdcwdl.wdl_18967?fo=json 200
# wrote data/item_metadata-gdcwdl.wdl_18967.json
# requested https://www.loc.gov/resource/g9112n.ct002339?fo=json 200
# wrote data/item_metadata-g9112n.ct002339.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ks-058?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ks-058.json
# requested https://www.loc.gov/resource/g3824j.ct003257?fo=json 200
# wrote data/item_metadata-g3824j.ct003257.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.me-061?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.me-061.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ME16?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ME16.json
# requested https://www.loc.gov/resource/g7823b.ct003291?fo=json 200
# wrote data/item_metadata-g7823b.ct003291.json
# requested https://www.loc.gov/resource/gmdtitlecolmaps.ca-053?fo=json 200
# wrote data/item_metadata-gmdtitlecolmaps.ca-053.json
# requested https://www.loc.gov/resource/gmdtitlecolfold.ca-053?fo=json 200
# wrote data/item_metadata-gmdtitlecolfold.ca-053.json
# items requested: 129
# errors: 0
# files written: 129

# %%
pictorial_results = pictorial_set.get('results', [])

csv_file_path = 'pictorial_metadata.csv'

extract_key = ["image_url"]

with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    header_values = set()
    for result in pictorial_results:
        item_value = result.get("item", "")
        if isinstance(item_value, dict):
            header_values.update(item_value.keys())

    header =  list(header_values) + extract_key
    csv_writer.writerow(header)

    for result in pictorial_results:
        item_value = result.get("item", {})
        row = [item_value.get(key, '') for key in header_values] + [result.get(key, '') for key in extract_key]
        csv_writer.writerow(row)

# %%
csv_output_file = 'pictorial_metadata.csv'

json_data_list = []

for filename in os.listdir('data'):
    if filename.endswith('.json'):
        json_file_path = os.path.join('data', filename)
        with open(json_file_path, 'r', encoding='utf-8') as json_file:
            data = json.load(json_file)
            item_data = data.get('item', {})
            item_data['image_url'] = data.get('image_url', '')
            item_data['created_published'] = ', '.join(item_data.get('created_published', []))
            json_data_list.append(item_data)

all_keys = set().union(*(item.keys() for item in json_data_list))

with open(csv_output_file, 'w', newline='', encoding='utf-8') as csv_output:
    csv_writer = csv.DictWriter(csv_output, fieldnames=all_keys)

    csv_writer.writeheader()

    for data in json_data_list:
        csv_writer.writerow({key: data.get(key, '') for key in all_keys})

# %% [markdown]
# ## Transforming

# %% [markdown]
# | source field name | source field path/dict name | target        | target namespace | notes |
# |-------------------|-----------------------------|---------------|------------------|-------|
# | Title | item['title'] | dc:title | DC Element | notes |
# | Date | item['date'] | dc:date | DC Element | notes |
# | Creator | item['contributor'] | dc:creator| DC Element | notes |
# | Type | item['format'] | dc:type | DC Element | notes |
# | Subject | item['subject']| dc:subject | DC Element | notes |
# | Coverage | item['location'] | dc:coverage | DC Element | notes |
# | Extent | item['medium'] | dcterms:extent | DC Element | notes |
# | Description | item['notes'] | dc:description | DC Element | notes |
# | Language | item['language'] | dc:language | DC Element | notes |
# | Publisher | item['created_published'] | dc:publisher | DC Element | notes |
# | Copyright Date | item['created_published'] | dc:publisher  | DC Element | notes |
# | Identifier | item['digital_id'] | dc:identifier | DC Element | notes |

# %%
input_csv_path = 'pictorial_metadata.csv'
output_csv_path = 'pictorial_metadata_select.csv'
transformed_csv_path = 'pictorial_metadata_transform.csv'

header_mapping = {
    'format': 'Type',
    'medium': 'Extent',
    'date': 'Date',
    'image_url': 'Image_URL',
    'notes': 'Description',
    'digital_id': 'Identifier',
    'contributors': 'Creator',
    'created_published': 'Publisher',
    'language': 'Language',
    'location': 'Location',
    'subjects': 'Subject',
    'title': 'Title'
}


with open(input_csv_path, 'r', encoding='utf-8') as input_csv, open(output_csv_path, 'w', newline='', encoding='utf-8') as output_csv:
    reader = csv.DictReader(input_csv)
    writer = csv.DictWriter(output_csv, fieldnames=header_mapping.values())

    writer.writeheader()

    for row in reader:
        mapped_row = {header_mapping[old_header]: row[old_header] for old_header in header_mapping}
        writer.writerow(mapped_row)

print(f"New CSV file with selected headers saved at: {output_csv_path}")

with open(output_csv_path, 'r', encoding='utf-8') as input_csv, open(transformed_csv_path, 'w', newline='', encoding='utf-8') as output_csv:
    reader = csv.DictReader(input_csv)

    new_headers = list(header_mapping.values())
    writer = csv.DictWriter(output_csv, fieldnames=new_headers)

    writer.writeheader()

    for row in reader:
        mapped_row = {new_header: row[new_header] for new_header in new_headers}
        writer.writerow(mapped_row)

print(f"New CSV file with updated headers saved at: {transformed_csv_path}")
# Out:
# New CSV file with selected headers saved at: pictorial_metadata_select.csv
# New CSV file with updated headers saved at: pictorial_metadata_transform.csv
